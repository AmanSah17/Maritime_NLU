# %%
import pandas as pd

# Load the pickle
df1 = pd.read_pickle(
    r"F:\PyTorch_GPU\maritime_monitoring_preprocessing\processed_data\AIS_2020_01_03.pkl"
)

# Keep only rows where VesselName is not null
df_clean = df1[df1["VesselName"].notna()]

# Keep only the required columns
columns_to_keep = [
    "MMSI",
    "BaseDateTime",
    "LAT",
    "LON",
    "SOG",
    "COG",
    "Heading",
    "VesselName",
    "CallSign",
    "VesselType",
]
df_clean = df_clean[columns_to_keep]

# Sort sequentially by MMSI and BaseDateTime
df_clean = df_clean.sort_values(by=["MMSI", "BaseDateTime"]).reset_index(drop=True)

print(df_clean.head())
print(f"✅ Total rows after cleaning: {len(df_clean)}")
df_clean
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       4 df1 = pd.read_pickle(
#       5     r"F:\PyTorch_GPU\maritime_monitoring_preprocessing\processed_data\AIS_2020_01_03.pkl"
#       6 )
#       8 # Keep only rows where VesselName is not null
# ----> 9 df_clean = df1[df1["VesselName"].notna()]
#      11 # Keep only the required columns
#      12 columns_to_keep = [
#      13     "MMSI",
#      14     "BaseDateTime",
#    (...)     22     "VesselType",
#      23 ]
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\frame.py:4104, in DataFrame.__getitem__(self, key)
#    4102 # Do we have a (boolean) 1d indexer?
#    4103 if com.is_bool_indexer(key):
# -> 4104     return self._getitem_bool_array(key)
#    4106 # We are left with two options: a single key, and a collection of keys,
#    4107 # We interpret tuples as collections only for non-MultiIndex
#    4108 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\frame.py:4166, in DataFrame._getitem_bool_array(self, key)
#    4163     return self.copy(deep=None)
#    4165 indexer = key.nonzero()[0]
# -> 4166 return self._take_with_is_copy(indexer, axis=0)
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\generic.py:4175, in NDFrame._take_with_is_copy(self, indices, axis)
#    4164 @final
#    4165 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4166     """
#    4167     Internal version of the `take` method that sets the `_is_copy`
#    4168     attribute to keep track of the parent dataframe (using in indexing
#    (...)   4173     See the docstring of `take` for full explanation of the parameters.
#    4174     """
# -> 4175     result = self.take(indices=indices, axis=axis)
#    4176     # Maybe set copy if we didn't actually change the index.
#    4177     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\generic.py:4155, in NDFrame.take(self, indices, axis, **kwargs)
#    4150     # We can get here with a slice via DataFrame.__getitem__
#    4151     indices = np.arange(
#    4152         indices.start, indices.stop, indices.step, dtype=np.intp
#    4153     )
# -> 4155 new_data = self._mgr.take(
#    4156     indices,
#    4157     axis=self._get_block_manager_axis(axis),
#    4158     verify=True,
#    4159 )
#    4160 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4161     self, method="take"
#    4162 )
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\internals\managers.py:913, in BaseBlockManager.take(self, indexer, axis, verify)
#     910 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     912 new_labels = self.axes[axis].take(indexer)
# --> 913 return self.reindex_indexer(
#     914     new_axis=new_labels,
#     915     indexer=indexer,
#     916     axis=axis,
#     917     allow_dups=True,
#     918     copy=None,
#     919 )
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\internals\managers.py:707, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     699     new_blocks = self._slice_take_blocks_ax0(
#     700         indexer,
#     701         fill_value=fill_value,
#     702         only_slice=only_slice,
#     703         use_na_proxy=use_na_proxy,
#     704     )
#     705 else:
#     706     new_blocks = [
# --> 707         blk.take_nd(
#     708             indexer,
#     709             axis=1,
#     710             fill_value=(
#     711                 fill_value if fill_value is not None else blk.fill_value
#     712             ),
#     713         )
#     714         for blk in self.blocks
#     715     ]
#     717 new_axes = list(self.axes)
#     718 new_axes[axis] = new_axis
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\internals\blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1370     allow_fill = True
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#    1379 if isinstance(self, ExtensionBlock):
#    1380     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1381     #  algos.take_nd call above.
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\array_algos\take.py:114, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     109         arr = cast("NDArrayBackedExtensionArray", arr)
#     110         return arr.take(
#     111             indexer, fill_value=fill_value, allow_fill=allow_fill, axis=axis
#     112         )
# --> 114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
#     117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\arrays\sparse\array.py:1069, in SparseArray.take(self, indices, allow_fill, fill_value)
#    1067     dtype = self.dtype
#    1068 elif allow_fill:
# -> 1069     result = self._take_with_fill(indices, fill_value=fill_value)
#    1070 else:
#    1071     return self._take_without_fill(indices)
#
# File f:\Maritime_NLU\mnlu\Lib\site-packages\pandas\core\arrays\sparse\array.py:1119, in SparseArray._take_with_fill(self, indices, fill_value)
#    1117     taken[old_fill_indices] = self.fill_value
#    1118 else:
# -> 1119     taken = self.sp_values.take(sp_indexer)
#    1121     # Fill in two steps.
#    1122     # Old fill values
#    1123     # New fill values
#    1124     # potentially coercing to a new dtype at each stage.
#    1126     m0 = sp_indexer[old_fill_indices] < 0
#
# KeyboardInterrupt:

# %%
df_clean
# Out:
#                MMSI        BaseDateTime       LAT       LON  SOG    COG  \
# 0            507027 2020-01-03 00:00:07  37.00648 -76.24921  0.0  277.8
# 1            507027 2020-01-03 00:01:17  37.00645 -76.24919  0.0  286.3
# 2            507027 2020-01-03 00:02:37  37.00646 -76.24917  0.0  276.2
# 3            507027 2020-01-03 00:03:47  37.00648 -76.24914  0.0  264.4
# 4            507027 2020-01-03 00:04:56  37.00645 -76.24913  0.3  209.7
# ...             ...                 ...       ...       ...  ...    ...
# 6470030  1073709206 2020-01-03 20:52:53  29.94075 -91.84231  0.0  318.7
# 6470031  1073709206 2020-01-03 20:54:04  29.94077 -91.84235  0.1  299.3
# 6470032  1073709206 2020-01-03 20:55:23  29.94074 -91.84230  0.1  289.5
# 6470033  1073709206 2020-01-03 20:56:24  29.94077 -91.84235  0.0  290.1
# 6470034  1073709206 2020-01-03 20:57:26  29.94079 -91.84237  0.1  287.6
#
#          Heading VesselName CallSign  VesselType
# 0          511.0  WEEKS 551  WBX3592        30.0
# 1          511.0  WEEKS 551  WBX3592        30.0
# 2          511.0  WEEKS 551  WBX3592        30.0
# 3          511.0  WEEKS 551  WBX3592        30.0
# 4          511.0  WEEKS 551  WBX3592        30.0
# ...          ...        ...      ...         ...
# 6470030    511.0     RAM 14  WDA6950        90.0
# 6470031    511.0     RAM 14  WDA6950        90.0
# 6470032    511.0     RAM 14  WDA6950        90.0
# 6470033    511.0     RAM 14  WDA6950        90.0
# 6470034    511.0     RAM 14  WDA6950        90.0
#
# [6470035 rows x 10 columns]

# %%
df_clean["VesselName"]
# Out:
# 0          WEEKS 551
# 1          WEEKS 551
# 2          WEEKS 551
# 3          WEEKS 551
# 4          WEEKS 551
#              ...
# 6470030       RAM 14
# 6470031       RAM 14
# 6470032       RAM 14
# 6470033       RAM 14
# 6470034       RAM 14
# Name: VesselName, Length: 6470035, dtype: object

# %%
print(
    f"Total Unique Vessel names present in the dataframe AIS_2020_01_03 , {len(df_clean['VesselName'])}"
)
# Out:
# Total Unique Vessel names present in the dataframe AIS_2020_01_03 , 6470035

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6470035 entries, 0 to 6470034
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   MMSI          int64
#  1   BaseDateTime  datetime64[ns]
#  2   LAT           float64
#  3   LON           float64
#  4   SOG           float64
#  5   COG           float64
#  6   Heading       float64
#  7   VesselName    object
#  8   CallSign      object
#  9   VesselType    float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(2)
# memory usage: 493.6+ MB

# %%
df_clean.describe()
# Out:
#                MMSI                   BaseDateTime           LAT  \
# count  6.470035e+06                        6470035  6.470035e+06
# mean   3.658396e+08  2020-01-03 12:10:42.412647936  3.527944e+01
# min    5.070270e+05            2020-01-03 00:00:00  7.086550e+00
# 25%    3.668985e+08            2020-01-03 06:06:57  2.964350e+01
# 50%    3.673537e+08            2020-01-03 12:23:20  3.271137e+01
# 75%    3.676632e+08            2020-01-03 18:14:14  4.064937e+01
# max    1.073709e+09            2020-01-03 23:59:59  7.049003e+01
# std    5.305722e+07                            NaN  8.409173e+00
#
#                 LON           SOG           COG       Heading    VesselType
# count  6.470035e+06  6.470035e+06  6.470035e+06  6.470035e+06  6.364000e+06
# mean  -9.583238e+01  1.951505e+00  2.095156e+02  3.723435e+02  4.371631e+01
# min   -1.783058e+02  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%   -1.172050e+02  0.000000e+00  1.219000e+02  2.230000e+02  3.100000e+01
# 50%   -9.038980e+01  0.000000e+00  2.297000e+02  5.110000e+02  3.100000e+01
# 75%   -8.086609e+01  3.000000e-01  3.012000e+02  5.110000e+02  6.000000e+01
# max    1.449452e+02  1.023000e+02  3.797000e+02  5.110000e+02  9.900000e+01
# std    2.224431e+01  5.877512e+00  1.110121e+02  1.759397e+02  1.977664e+01

# %%
import os
import sqlite3
import pandas as pd

# ✅ Path to your SQLite DB file
db_path = r"F:\Maritime_NLU\backend\src\maritime_data.db"

# ✅ Make sure folder exists
os.makedirs(os.path.dirname(db_path), exist_ok=True)

# ✅ Connect to database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# ✅ Drop existing table (optional reset)
cursor.execute("DROP TABLE IF EXISTS vessel_data;")
conn.commit()

# ✅ Create fresh table schema
create_table_query = """
CREATE TABLE IF NOT EXISTS vessel_data (
    MMSI INTEGER,
    BaseDateTime TEXT,
    LAT REAL,
    LON REAL,
    SOG REAL,
    COG REAL,
    Heading REAL,
    VesselName TEXT,
    CallSign TEXT,
    VesselType REAL
);
"""
cursor.execute(create_table_query)
conn.commit()
print("✅ Created fresh table: vessel_data")

# ✅ Store DataFrame in chunks
chunksize = 100_000
for i in range(0, len(df_clean), chunksize):
    chunk = df_clean.iloc[i : i + chunksize]
    chunk.to_sql("vessel_data", conn, if_exists="append", index=False)
    print(f"Inserted rows {i:,} – {min(i+chunksize, len(df_clean)):,}")

print("✅ All data stored in SQLite database!")

# ✅ Verify row count
count_df = pd.read_sql("SELECT COUNT(*) AS total_rows FROM vessel_data;", conn)
print("\nTotal rows in table:", count_df["total_rows"].iloc[0])

# ✅ Example 1: Filter by MMSI
mmsi_number = 983192101
query_mmsi = f"""
    SELECT * FROM vessel_data 
    WHERE MMSI = {mmsi_number}
    ORDER BY BaseDateTime ASC
    LIMIT 1000;
"""
df_vessel = pd.read_sql(query_mmsi, conn)
print(f"\nFetched {len(df_vessel)} records for MMSI = {mmsi_number}")
print(df_vessel.head())

# ✅ Example 2: Filter by datetime range
start = "2020-01-03 00:00:00"
end = "2020-01-03 12:00:00"

query_time = f"""
    SELECT * FROM vessel_data
    WHERE BaseDateTime BETWEEN '{start}' AND '{end}'
    ORDER BY BaseDateTime ASC
    LIMIT 1000;
"""
df_time = pd.read_sql(query_time, conn)
print(f"\nFetched {len(df_time)} records between {start} and {end}")
print(df_time.head())

# ✅ Close connection
conn.close()
print("\n🔒 Connection closed successfully.")
# Out:
# ✅ Created fresh table: vessel_data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 40
#      38 # ✅ Store DataFrame in chunks
#      39 chunksize = 100_000
# ---> 40 for i in range(0, len(df_clean), chunksize):
#      41     chunk = df_clean.iloc[i : i + chunksize]
#      42     chunk.to_sql("vessel_data", conn, if_exists="append", index=False)
#
# NameError: name 'df_clean' is not defined

# %%
df_clean["MMSI"].unique()
# Out:
# array([    507027,    1056261,    1193046, ...,  983192101,  983780008,
#        1073709206], shape=(11594,))

# %%
import sqlite3
import pandas as pd
import os

db_path = r"F:\Maritime_NLU\backend\backend\maritime_data.db"

# Check that file exists
print("Database exists:", os.path.exists(db_path))
print("Database size (MB):", os.path.getsize(db_path) / 1024 / 1024)

# Connect
conn = sqlite3.connect(db_path)
# Out:
# Database exists: True
# Database size (MB): 535.28515625

# %%
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
print("Tables in this database:")
print(tables)
# Out:
# Tables in this database:
#           name
# 0  vessel_data

# %%
row_count = pd.read_sql("SELECT COUNT(*) AS total_rows FROM vessel_data;", conn)
print(row_count)
# Out:
#    total_rows
# 0     6470035

# %%
# Example 1: Filter by MMSI
mmsi_number = 983192101
df_vessel = pd.read_sql(
    f"""
    SELECT * FROM vessel_data 
    WHERE MMSI = {mmsi_number}
    ORDER BY BaseDateTime ASC
    LIMIT 1000;
""",
    conn,
)

# Example 2: Filter by datetime range
start = "2020-01-03 00:00:00"
end = "2020-01-03 12:00:00"

df_time = pd.read_sql(
    f"""
    SELECT * FROM vessel_data
    WHERE BaseDateTime BETWEEN '{start}' AND '{end}'
    ORDER BY BaseDateTime ASC
    LIMIT 1000;
""",
    conn,
)

# %%
import os


print("Database exists:", os.path.exists(db_path))
print("Database size (MB):", os.path.getsize(db_path) / 1024 / 1024)
# Out:
# Database exists: True
# Database size (MB): 535.28515625

# %%
import os

print(os.getcwd())
# Out:
# f:\Maritime_NLU\backend
